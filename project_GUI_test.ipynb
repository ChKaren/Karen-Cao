# %%
import random
import string
from my_module.functions_2 import *

# %%
# list of cognitive science major code in AScii version

decoded_major_code = [[99, 103, 50, 53] , [99, 103, 50, 57] , [99, 103, 51, 53] ,
                      [99, 103, 51, 52] , [99, 103, 51, 49] , [99, 103, 51, 51]]

# %%
# data for all cognitive lower division courses

lower = ['COGS1' , 'COGS13' , 'COGS14A' , 'COGS14B' ,  'COGS17']
lower_alternative = ['DSGN1 or COGS10' , 'COGS18 or any in CSE7 CSE8A CSE8B CSE11']

# %%
# data for cognitive core courses 
# series courses indicate the descripition for any two courses

core = ['COGS100' , 'COGS108']
core_series_a = ['COGS101A' , 'COGS101B' , 'COGS101C']
core_series_b = ['COGS107A' , 'COGS107B' , 'COGS107C']

# %%
# data for approved elective cognitive courses for major code CG25

elective_cognitivesciences = ['102B Cognitive Ethnography',
                              '102C Cognitive Design Studio',
                              '109 Modeling and Data Analysis',
                              '110 The Developing Mind',
                              '115 Neurological Dev. & Cognitive Change',
                              '118A Intro to Machine Learning I',
                              '118B Intro to Machine Learning II',
                              '118C Neural Signal Processing',
                              '118D Math. Stat. for Behavioral Data Analysis',
                              '119 Programming for Experimental Research',
                              '120 Human Computer Interaction',
                              '121 Human Computer Interaction Programming',
                              '122 Interaction Design Startup',
                              '123 Social Computing',
                              '124 HCI Technical Systems Research',
                              '125 Advanced Interaction Design',
                              '126 Human-Computer Interaction',
                              '143 Animal Cognition',
                              '144 Social Cognition',
                              '151 Analogy and Conceptual Systems',
                              '152 Cognitive Foundations of Mathematics',
                              '153 Language Comprehension',
                              '154 Comm. Disorders in Children & Adults',
                              '155 Gesture and Cognition',
                              '156 Language Development',
                              '157 Music and the Mind',
                              '160 Upper Division Seminar on Special Topics',
                              '163 Metabolic Disorders/Brain',
                              '164 Neurobiology of Motivation',
                              '169 Genetic Information/Behavior',
                              '170 Brain Waves Across Scales',
                              '171 Mirror Neuron System',
                              '172 Brain Disorders and Cognition',
                              '174 Drugs: Brain, Mind and Culture',
                              '175 Neuropsyc. Basis Alternate States/Conscious.',
                              '176 From Sleep to Attention',
                              '177 Space and Time in the Brain',
                              '178 Genes, Brains & Behavior',
                              '179 Electrophysiology of Cognition',
                              '180 Neural Coding/Sensory Systems',
                              '181 Neural Networks and Deep Learning',
                              '184 Modeling the Evolution of Cognition',
                              '185 Adv. Machine Learning Methods',
                              '187A Usability & Info. Architecture',
                              '187B Practicum in Pro Web Design',
                              '188 AI Algorithm and Social Language',
                              '189 Brain Computer Intersurface']

# data for elective cognitive science with specialization in neuroscience 
elective_cognitive_science_cg29 = ['115 Neurological Dev. & Cognitive Change',
                                   '119 Programming for Experimental Research',
                                   '143 Animal Cognition',
                                   '154 Comm. Disorders in Children & Adults',
                                   '160 Upper Division Seminar on Special Topics',
                                   '163 Metabolic Disorders/Brain',
                                   '164 Neurobiology of Motivation',
                                   '169 Genetic Information/Behavior',
                                   '170 Brain Waves Across Scales',
                                   '171 Mirror Neuron System',
                                   '172 Brain Disorders and Cognition',
                                   '174 Drugs: Brain, Mind and Culture',
                                   '175 Neuropsyc. Basis Alternate States/Conscious.',
                                   '176 From Sleep to Attention',
                                   '177 Space and Time in the Brain',
                                   '178 Genes, Brains & Behavior',
                                   '179 Electrophysiology of Cognition',
                                   '180 Neural Coding/Sensory Systems',
                                   '184 Modeling the Evolution of Cognition'] 

# data for elective cognitive science with specialization in machine learning
elective_cognitive_science_cg35 = ['109 Modeling and Data Analysis',
                                   '118A Intro to Machine Learning I',
                                   '118B Intro to Machine Learning II',
                                   '118C Neural Signal Processing',
                                   '118D Math. Stat. for Behavioral Data Analysis',
                                   '160 Upper Division Seminar on Special Topics',
                                   '180 Neural Coding/Sensory Systems',
                                   '181 Neural Networks and Deep Learning',   
                                   '185 Adv. Machine Learning Methods',
                                   '188 AI Algorithm and Social Language',
                                   '189 Brain Computer Intersurface']

#data for elective cognitive science with specialization in language
elective_cognitive_science_cg34 = ['110 The Developing Mind',
                                  '119 Programming for Experimental Research',
                                  '143 Animal Cognition',
                                  '144 Social Cognition',
                                  '151 Analogy and Conceptual Systems',
                                  '152 Cognitive Foundations of Mathematics',
                                  '153 Language Comprehension',
                                  '154 Comm. Disorders in Children & Adults',
                                  '155 Gesture and Cognition',
                                  '156 Language Development',
                                  '157 Music and the Mind',
                                  '160 Upper Division Seminar on Special Topics',
                                  '171 Mirror Neuron System'] 

#data for elective cognitive science with specialization in neuroscience clinical 
elective_cognitive_science_cg31 = ['154 Communication Disordersin Children + Adults',
                                   '163 Metabolic Disorders/Brain',
                                   '171 Mirror Neuron System',
                                   '172 Brain Disorders and Cognition',
                                   '174 Drugs: Brain, Mind and Culture',
                                   '175 Neuropsyc. Basis Alternate States/Conscious',
                                   '176 From Sleep to Attention',]

#data for elective cognitive science with specialization in hci
elective_cognitive_science_cg33 = ['COGS102A: Congitive perspectives',
                                   '102B Cognitive Ethnography',
                                   '102C Cognitive Design Studio',
                                   '119 Programming for Experimental Research',
                                   '120 Human Computer Interaction',
                                   '121 Human Computer Interaction Programming',
                                   '122 Interaction Design Startup',
                                   '123 Social Computing',
                                   '124 HCI Technical Systems Research',
                                   '125 Advanced Interaction Design',
                                   '126 Human-Computer Interaction',
                                   '160 Upper Division Seminar on Special Topics',
                                   '187A Usability & Info. Architecture',
                                   '187B Practicum in Pro Web Design',
                                   '188 AI Algorithm and Social Language',
                                   '189 Brain Computer Intersurface']

# %%
# approved phychology course for major code CG25
elective_phychology = ['100 Clinical Psychology',
                       '111A Research Methods I',
                       '111B Research Methods II',
                       '115A Laboratory in Cognitive Psychology',
                       '115B Laboratory in Cognitive Psychology II',
                       '116 Lab. in Clinical Psychology Research',
                       '120 Learning and Motivation',
                       '122 Mechanisms of Animal Behavior',
                       '123 Cognitive Control + Frontal Lobe Function',
                       '125 Clinical Neuropsychology',
                       '129 Logic of Perception',
                       '132 Hormones and Behavior',
                       '133 Circadian Rhythms—Biological Clocks',
                       '134 Eating Disorders',
                       '138 Sound and Music Perception',
                       '140 Lab/Human Behavior',
                       '144 Memory and Amnesia',
                       '145 Psychology of Language',
                       '150 Cognitive Neuroscience of Vision',
                       '159 Psychological Basis of Perception',
                       '168 Psychological Disorders of Childhood',
                       '169 Brain Damage and Mental Functions',
                       '170 Cognitive Neuropsychology',
                       '171 Neurobiology of Learning and Memory',
                       '174 Visual Cognition',
                       '176 Creativity',
                       '179 Drugs, Addiction, Mental Disorder',
                       '181 Drugs and Behaviors',
                       '182 Illusions and the Brain',
                       '188 Impulse Control Disorders',
                       '189 Brain, Behavior, and Evolution']

# elective psychology for students with specialization, CG33
elective_psychology_cg33 = ['161 Introduction to Engineering Psychology']

#elective psychology for students with specialization, CG29
elective_psychology_cg29 = ['123 Cognitive Control + Frontal Lobe Function',
                            '132 Hormones and Behavior',
                            '133 Circadian Rhythms—Biological Clocks',
                            '150 Cognitive Neuroscience of Vision', 
                            '168 Psychological Disorders of Childhood',
                            '169 Brain Damage and Mental Functions',
                            '174 Visual Cognition', 
                            '179 Drugs, Addiction, Mental Disorder',
                            '181 Drugs and Behaviors',
                            '182 Illusions and the Brain',]

#elective psychology for students with specialization, CG31
elective_psychology_cg31 = ['100 Clinical Psychology','120 Learning and Motivation',
                            '125 Clinical Neuropsychology',
                            '124 Introduction to Clinicial Neuropsychology',
                            '134 Eating Disorders',
                            '144 Memory and Amnesia',
                            '154 Behavior Modification',
                            '155 Social Psychology and Medicine',
                            '168 Psychological Disorders of Childhood',
                            '169 Brain Damage and Mental Functions',
                            '170 Cognitive Neuropsychology',
                            '179 Drugs, Addiction, Mental Disorder',
                            '181 Drugs and Behaviors',
                            '188 Impulse Control Disorders']

#elective psychology for students with specialization, CG34
elective_psychology_cg34 = ['115A Laboratory in Cognitive Psychology',
                            '115B Laboratory in Cognitive Psychology II',
                            '128 Psychology of Reading',
                            '145 Psychology of Language',
                            '156 Cognitive Declopment in Infancy']

# %%
# for cognitive science students with major code CG25, the genral cogs
elective_philosophy = ['134 Philosophy of Language',
                       '136 Philosophy of Mind',
                       '149 Philosophy of Psychology',
                       '150 Philosophy of the Cognitive Sciences',
                       '151 Philosophy of Neuroscience',
                       '163 Bio-Medical Ethics',
                       '164 Technology and Human Values']
# for students with specialization, major code CG33
elective_philosophy_cg33 = ['PHIL 164 Technology and Human values']

# %%
# for cognitive science students with major code CG25, the genral cogs
elective_linguistics = ['112 Speech Sounds and Speech Disorders',
                        '120 Morphology',
                        '121 Syntax I',
                        '125 Syntax II',
                        '130 Semantics',
                        '155 Evolution of Language',
                        '165 Computational Linguistics',
                        '169 Principles/Discourse and Dialog',
                        '170 Psycholinguistics',
                        '171 Child Language Acquisition',
                        '180 Language Representation in the Brain',
                        '181 Language Processing in the Brain']

# for students with specialization, major code CG29
elective_linguistics_cg29 = ['180 Language Representation in the Brain',
                             '181 Language Processing in the Brain']

# for students with specialization, major code CG35
elective_linguistics_cg35 = ['LIGN 167 Deep Learning for Nat.Lang.Understanding']

# for students with specialization, major code CG34
elective_linguistics_cg34 = ['LIGN 148:Psycholinguistics of Sign Language',
                             'LIGN 155 Evolution of Language',
                             'LIGN 170 Psycholinguistics',
                             'LIGN 171 Child Lang Acquisition',
                             'LIGN 174 Gender and Language in Society' ,
                             'LIGN 175 Sociolinguisitics',
                             'LIGN 180 Language Representation in the Brain',
                             'LIGN 181:Language Processing in the Brain']

# %%
elective_computerscience = ['100 Advanced Data Structures',
                            '101 Design & Analysis of Algorithms',
                            '102 File and Storage Structures',
                            '130 Program Lang: Principles & Paradigms',
                            '133 Information Retrieval',
                            '150 Program Lang for Art. Intelligence',
                            '160 Intro to Parallel Computation']

## for students with specialization, major code CG35
elective_computer_science_cg35 = ['100: Advanced Data Structures',
                                ' 101 Design and Analysis of Algorithms',
                                ' 102 Storage System Architectures',
                                ' 105 Theory of Computability',
                                ' 130 Program Lang: Prin. and Paradigms',
                                ' 131 Compiler Construction',
                                '150 Intro to AI: Search and Reasoning',
                                ' 151 Intro to AI: Statistical Approaches',
                                '160 Intro to Parallel Computation']

## for students with specialization, major code CG33
elective_computer_science_cg33 = ['CSE 100: Advanced Data Structures',
                                  'CSE 101: Design and Analysis of Algorithms',
                                  'CSE 102: Storage System Architectures',
                                  'CSE 110: Software Engineering',
                                  'CSE 111: Object Oriented Software Design',
                                  'CSE 118: Ubiquitous Computing',
                                  'CSE 130: Programming Lang: Principles and Paradigms',
                                  'CSE 132A: Database System Principles',
                                  'CSE 132B: Database Systems Applications',
                                  'CSE 133: Information Retrieval',
                                  'CSE 134A: Web Server Languages',
                                  'CSE 134B: Web Client Languages',
                                  'CSE 135: Server-side Web Applications',
                                  'CSE 150: Introduction to Artificial Intelligence: Search and Reasoning',
                                  'CSE 151: Introduction to Artificial Intelligence:Statistical Approaches',
                                  'CSE 152: Intro Computer Vision',
                                  'CSE 165: 3D User Interaction',
                                  'CSE 167: Computer Graphics',
                                  'CSE 171: User Interface Design',
                                  'CSE 176A: Maker Topics: Health Care Robotics']

# %%
elective_communication_cg33 = ['COMM 101E: Media Production Lab:Ethnographic Methods for Media Production',
                               'COMM 101M: Media Production Lab:Communicating and Computers',
                               'COMM 102C: Practicum in New Media &Community Life',
                               'COMM 105G: Computer Games Studies',
                               'COMM 106I: Internet Industry',
                               'COMM 110T: LLC: Language, Thought & Media',
                               'COMM 112M: Communication and Social Machines',
                               'COMM 120N: Advanced Media Production:News Media Workshop',
                               'COMM 124A: Critical Design: Advanced Studio',
                               'COMM 124B: Critical Design: Topic Studio',
                               'COMM 151: The Information Age: In Fact and Fiction',
                               'COMM 172: Adv. Studies in Mediation and Interaction',
                               'COMM 173: Interaction with Technology']

elective_communication = ['102C Practicum in New Media and Community Life']

# %%
#
elective_biology_animal_cg29 = ['BIPN 100: Mammalian Physiology I',
                               'BIPN 105: Animal Physiology Lab',
                               'BIPN 144: Developmental Neurobiology',
                               'BIPN 146: Computational Neurobiology',
                               'BIPN 148: Cellular Basis of Learning and Memory']

elective_biology_animal_cg31 = ['BIPN 100: Mammalian Physiology I',
                                'BIPN 105: Animal Physiology Lab'] 

elective_biology_animal_cg35 = ['BIPN 146 Computational Neurobiology']

# %%
elective_biochemistry =['BIBC 100 Structural Biochemistry',
                        'BIBC 102 Metabolic Biochemistry']

# %%
elective_chemistry_cg29 = [ '143B Organic Chemistry Laboratory',
                            '143C: Organic Chemistry Laboratory']

# %%
elective_math_cg35 = ['MATH 170A: Numerical/Linear Algebra',
                      'MATH 170B: Numerical/Approx + Nonlinear',
                      'MATH 170C: Numerical/Differential Equations',
                      'MATH 180A: Introduction to Probability',
                      'MATH 180B: Intro. to Stochastic Processes I',
                      'MATH 180C: Intro. to Stochastic Processes II',
                      'MATH 189: Exploratory Data Analysis/Inference']

# %%
elective_visual_arts = ['VIS 140: Digital Imaging: Image and Interactivity',
                        'VIS 145A: Digital Media I: Time, Movement,Sound',
                        'VIS 145B: Time- and Process-Based Digital Media II',
                        'VIS 147A: Electronic Technologies for Art I',
                        'VIS 147B: Electronic Technologies for Art II',
                        'VIS 149: Seminar in Contemporary Computer Topics',
                        'VIS 176: 16mm Filmmaking',
                        'VIS 177: Scripting Strategies',
                        'VIS 180A: Documentary Evidence and the Construction of Authenticity in Current Media Practices',
                        'VIS 180B: Fiction and Allegory in Current Media Practices',
                        'VIS 182: Advanced Editing',
                        'VIS 186: Advanced Filmmaking Strategies']

# %%
elective_educationstudies = ['114 Cognitive Dev. and Interactive Computing Env.',
                             '115 Cognitive Development and Education',
                             '116 Psyc. of Teach./Struct. of Info/Human Learning',
                             '117 Language, Culture, and Education',
                             '136 Intro to Acad. Tut. Of Sec. Sch. Stud']

elective_education_studies_cg33 = ['EDS 114: Cog. Development/Interactive Computing Env.',
                                   'EDS 124AR: Teaching Comp. in a Digital World',
                                   'EDS 124BR: Teaching Comp. Thinking for Everyone']

# %%
elective_ece = ['ECE 161A: Introduction to Digital Signal Processing',
                'ECE 161B: Digital Signal Processing I',
                'ECE 161C: Applications of Digital Signal Processing',
                'ECE 172A: Introduction to Intelligent Systems:Robotics and Machine Intelligence',
                'ECE 187: Introduction to Biomedical Imaging and Sensing']

# %%
elective_design = ['100 Prototyping']

computing_arts = ['ICAM 101: Digital Imaging: Image and Interactivity',
                  'ICAM 102: Digital Media I: Time, Movement,Sound',
                  'ICAM 120: Virtual Environments',
                  'ICAM 130: Seminar in Contemporary Computer Topics']

elective_engineering = ['ENG 100D Design for Development']

# %%
sociology = ['SOCI 116: Gender and Language in Society *',
             'SOCI 117: Language, Culture, and Education',
             'SOCI 118E: Sociology of Language']

# %%
def upper_core():
    output = []
    Temp_1 = random.choice(core)
    output.append( Temp_1)
    Temp_2 = random.sample(set(core_series_a),2)
    output.append( Temp_2)
    Temp_3 = random.sample(set(core_series_b),2)
    output.append( Temp_3)
    return output

# %%
def remove_punctuation(input_string):
    out_string= ''
    for item in input_string:
        if item not in string.punctuation:
            out_string= out_string+item
    return out_string

# %%
def prepare_text(input_string):
    temp_string=input_string.lower()
    temp_string=remove_punctuation(temp_string)
    out_list=list(temp_string)
    return(out_list)

# %%
def decoder(input_string):
    output =[]
    temp = input_string
    for i in range(len(temp)):
        output.append( ord(temp[i]))
    return output

# %%
from tkinter import*
from tkinter import messagebox

window = Tk()


 

def check_condition():
    
    # convert the user input to a list of ASCII  numbers
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    
    
    if Checked in decoded_major_code:
            
            # delete make the user input chageable only the latest input will be take into operaction
            Text.delete("1.0", END)
            Text.insert(END,"Now,go and choose your courses") 
            
    elif Checked not in decoded_major_code:
            #insert method will attach the string in to the text space created
            Text.delete("1.0", END)
            Text.insert(END,"Alert! , Sorry! The course you entered is not in our list")
    
        
                              
    

# set the label  as Major code which  unchangable for user
l_1 = Label(window,text = "Major code")
# grid methon set the position of the label 
l_1.grid(row=0,column=0)
 
# convert the user input to string    
MajorCode_text= StringVar()
# entry method  make input possible
e1 = Entry(window,textvariable = MajorCode_text)
e1.grid(row=0,column=1)

# text for the characters on the button unchangable for user
b1 = Button(window, text="check", command =check_condition, width=25)
#command set the ooperaction if the button is clicked by user 
b1.grid(row=0, column=2) 

# white space for result of the check function
Text=Text(window,height=1,width=60)
Text.grid(row=0,column=3) 
  


    

# set the place to display the content    
list1 = Listbox(window,height=9,width=55,selectmode = EXTENDED)
# Extended mode will displace every result after click
list1.grid(row=1,column=0,rowspan=14,columnspan=2)


# window to display the scrollbar
sb1=Scrollbar(window)
# rowspan to merge server row into one
sb1.grid(row=2,column=2,rowspan=5)

# attach y scrollbar to list, so that user could see history record
list1.configure(yscrollcommand=sb1.set)
sb1.configure(command=list1.yview)


# attach x scrollbar to list , horizontally scroll to see the content
sb2=Scrollbar(window, orient=HORIZONTAL)
#columnspan merge assigned number of column into one
sb2.grid(row=15,column=1,columnspan=2)

# attach x scrollbar to list, so that user could see history record and scroll horizontally
list1.configure(xscrollcommand=sb2.set)
sb2.configure(command=list1.xview)


 



#button and command function for lower_course
def lower_course():
    """
    Converts an input string into a string containing the unicode code points.
    
          Parameters
          ----------
          no user input
        
          Returns
          -------
          output_string : string if conditions are not met
          output_list:  if conditons are met 
          functions below follow the same pattern 
     """
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output=[]
    
    
    if Checked in decoded_major_code:
        output.append(random.choice(lower))
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
         output.append('You do not have to take course from this department')
    
    
    return output


def insertListLower():
    
    list1.insert(0,lower_course())




#button and command function for lower_alternative_course
def lower_alternative_course():
    
    output=[]
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    
    
    if Checked in decoded_major_code:
        
        output.append(random.choice(lower_alternative))
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')  
    else:
        
        output.append('You do not have to take course from this department')
        
        
    return output    
         
def insertlower_alternative_course():
    
    # assign output from previous function to listbox to display
    list1.insert(0,lower_alternative_course())
    



#button and command function for elective cognitive science courses
def select_cogs():
    
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output=[]
    
    if Checked == [99, 103, 50, 53]:
        
        output.append(random.sample(set(elective_cognitivesciences),3))
        
        
    elif Checked ==[99, 103, 50, 57]:
        
        output.append(random.sample(set(elective_cognitive_science_cg29),3))
        
        
    elif Checked == [99, 103, 51, 53]:
        
        output.append(random.sample(set(elective_cognitive_science_cg35),3))
        
        
    elif Checked == [99, 103, 51, 52]:
        
        output.append(random.sample(set(elective_cognitive_science_cg34),3))
        
        
    elif Checked == [99, 103, 51, 49]:
        
        output.append(random.sample(set(elective_cognitive_science_cg31),3))
        
        
    elif Checked ==[99, 103, 51, 51]:
        
        output.append(random.sample(set(elective_cognitive_science_cg33),3))
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('why you here ???')
        
        
    return output


def insertlistselect_cogs():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_cogs())
    



#button and command function for elective psychology courses

def select_pshy():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output=[]
    
    if Checked == [99, 103, 50, 53]:
        
        output.append(random.sample(set(elective_phychology),3))
        
        
    elif Checked ==[99, 103, 50, 57]:
        
        output.append(random.sample(set(elective_psychology_cg29),3))
        
        
    elif Checked == [99, 103, 51, 49]:
        
        output.append(random.sample(set(elective_psychology_cg31),3))
        
        
    elif Checked == [99, 103, 51, 51]:
        
        output.append(random.choice(elective_psychology_cg33))
        
        
    elif Checked ==[99, 103, 51, 52]:
        
        output.append(random.sample(set(elective_psychology_cg34),3)) 
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
        
        
    return output
def insertselect_pshy():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_pshy())
    


#  button and command function for elective cse courses
def select_cse():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """  
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output=[]
    
    
    if Checked == [99, 103, 50, 53]:
        output.append(random.sample(set(elective_computerscience),3))
   

    elif Checked == [99, 103, 51, 53]:
        output.append(random.sample(set(elective_compter_science_cg35),3))
   

    elif Checked == [99, 103, 51, 51]:
        output.append(random.sample(set(elective_computer_science_cg33),3))
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
        
        
    return output    
def insertselect_cse():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_cse())


# function for select courses and command function to insert 
def select_comm():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
  
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output=[]
    
    
    if Checked == [99, 103, 50, 53]:
        
        output.append(random.choice(elective_communication))
        
        
    elif Checked == [99, 103, 51, 51]:
        
        output.append(random.sample(set(elective_communication_cg33),3))
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
        
        
    return output
def insertselect_comm():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_comm())
    
    
    
    
#function for select courses and command function to insert 
def select_biochem():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
 
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output=[]
  

    if Checked ==[99, 103, 50, 57]:
        
        output.append(random.choice(elective_biochemistry))
    
    
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        output.append('You do not have to take course from this department')

        
    return output

def insertselect_biochem():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_biochem()) 
    
    
# function for select courses and command function to insert 

    
    
    
def select_visual_arts():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output=[]
    
        
    if  Checked == [99, 103, 51, 51]:
        
        output.append(random.sample(set(elective_visual_arts),3))
        
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
        
        
    return output 
def insertselect_visual_arts():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_visual_arts())


#function for select courses and command function to insert 
def select_math():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """

    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output=[]
    
    
    if Checked == [99, 103, 51, 53]:
        
        output.append(random.sample(set(elective_math_cg35),3))
        
    
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
        
        
    return output

def insertselect_math():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_math())
 




 #function for select courses and command function to insert 
def select_ece():
    
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """    

    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output = []
      
        
    if Checked == [99, 103, 51, 51]:
        
        output.append(random.sample(set(elective_ece),2))
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
        
        
    return output 

def insertselect_ece():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_ece())
    
    
    
#function for select courses and command function to insert     
def select_ling():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
  
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output = []
    
    
    if Checked == [99, 103, 50, 53]:
        
        output.append(random.sample(set(elective_linguistics),3))
        
        
    elif Checked == [99, 103, 50, 57]:
        
        output.append(random.choice(elective_linguistics_cg29))
        
        
    elif Checked == [99, 103, 51, 53]:
        
        output.append(elective_linguistics_cg35)
        
        
    elif Checked == [99, 103, 51, 52]:
        
        output.append(random.sample(set(elective_linguistics_cg34),3))
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
        
        
    return output  

def insertselect_ling():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_ling()) 
    
    
#function for select courses and command function to insert 
def select_bio_nero():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output = []
  

    if  Checked ==[99, 103, 50, 57]:
        
        output.append(random.sample(set(elective_biology_animal_cg29),2))
        
        
    elif Checked == [99, 103, 51, 53]:
        
        output.append(random.choice(elective_biology_animal_cg35))
    
    
    elif Checked == [99, 103, 51, 49]:
        
         output.append(random.choice(elective_biology_animal_cg31))
   

    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')

        
    return output  

def insertselect_bio_nero():
    list1.insert(0,select_bio_nero())  
    
#function for select courses and command function to insert 
def select_chemistry():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output = []
    
    
    if  Checked ==[99, 103, 50, 57]:
        
        output.append(random.choice(elective_chemistry_cg29 ))
        
        
   
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
  

    return output
    
def insertselect_chemistry():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_chemistry())
    
#function for select courses and command function to insert 
def select_cg33special():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """

    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output = []
    
    
    if Checked == [99, 103, 51, 51]:
        
        choice_a = random.sample(set(computing_arts),2)
        output.append(choice_a)
        
        
        choice_c = random.choice(elective_engineering)
        output.append(choice_c)
        
        
        output.append(random.choice(elective_design))
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
         output.append('You do not have to take course from this department')
  

    return output  

def insertselect_cg33special():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_cg33special())
    
    
#function for select courses and command function to insert 
def select_edustudy():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output = []
    
    
    if Checked == [99, 103, 50, 53]:
        
        output.append(random.sample(set(elective_educationstudies),2))
        
        
    elif Checked == [99, 103, 51, 51]:
        
        output.append(random.choice(elective_education_studies_cg33))
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
        
        
    return output  

def insertselect_edustudy():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_edustudy())
    
    
#function for select courses and command function to insert 
def select_phil():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output = []
    
    
    if Checked == [99, 103, 50, 53]:
        
        output.append(random.sample(set(elective_phychology),3))
        
        
    elif Checked == [99, 103, 51, 51]:
        
        output.append(random.choice(elective_psychology_cg33))
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
        
        
    return output

def insertselect_phil():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_phil())
    
#function for select courses and command function to insert 

def select_sociology():
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output = []
    
    
    if Checked == [99, 103, 51, 52]:
        
        output.append(random.choice(sociology))
        
        
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
        output.append('You do not have to take course from this department')
  

    return output 

def insertselect_sociology():
    
    # assign output from previous function to listbox to display
    list1.insert(0,select_sociology())

    
def upper_core():
    
    """
    Converts an input string into a string containing the unicode code points.
    
    Parameters
    ----------
    no user input
        
    Returns
    -------
    output_string : string if conditions are not met
    output_list:  if conditons are met 
    functions below follow the same pattern 
    """
    
    Checked = decoder(prepare_text(remove_punctuation(MajorCode_text.get())))
    output = []
    
    
    if Checked in decoded_major_code:
        Temp_1 = random.choice(core)
        output.append( Temp_1)
        Temp_2 = random.sample(set(core_series_a),2)
        output.append( Temp_2)
        Temp_3 = random.sample(set(core_series_b),2)
        output.append( Temp_3)
    
        
                      
    elif Checked not in decoded_major_code:
        
        output.append('Sorry,no course for you.The programmer is trying to fix it ')
    else:
        
         output.append('You do not have to take course from this department')
    
    
    return output
    
def insertupper_core():
    
    # assign output from previous function to listbox to display
    list1.insert(0,upper_core())

#window for display the button
b1 = Button(window, text="lower", command = insertListLower, width=25)
b1.grid(row=1, column=3)

#text to indicate the words on the button
b1 = Button(window, text="lower alternatives", command = insertlower_alternative_course, width=35)
b1.grid(row=2, column=3)  

#command set the function, click will triggle the function to operate no user input needed
b1 = Button(window, text="Cognitive Science", command = insertlistselect_cogs, width=35)
b1.grid(row=3, column=3)

# width set the length of the button
b1 = Button(window, text="Psychology", command = insertselect_pshy, width=35)
b1.grid(row=4, column=3)
 
# later setup will be the same    
b1 = Button(window, text="Computer Science", command = insertselect_cse, width=35)
b1.grid(row=5, column=3)

b1 = Button(window, text="Communication", command = insertselect_comm, width=35)
b1.grid(row=6, column=3)

b1 = Button(window, text="visual arts", command = insertselect_visual_arts, width=35)
b1.grid(row=7, column=3)

b1 = Button(window, text="math", command = insertselect_math, width=35)
b1.grid(row=8, column=3)

b1 = Button(window, text="electrical engineer", command = insertselect_ece, width=35)
b1.grid(row=9, column=3)

b1 = Button(window, text="linguistics", command = insertselect_ling, width=35)
b1.grid(row=10, column=3)

b1 = Button(window, text="biochemistry", command = insertselect_biochem, width=35)
b1.grid(row=11, column=3)

b1 = Button(window, text="biology animal ", command = insertselect_bio_nero, width=35)
b1.grid(row=12, column=3)

b1 = Button(window, text="chemistry", command = insertselect_chemistry, width=35)
b1.grid(row=13, column=3)

b1 = Button(window, text="Design and interaction special course", command = insertselect_cg33special, width=35)
b1.grid(row=14, column=3)

b1 = Button(window, text="education studies", command = insertselect_edustudy, width=35)
b1.grid(row=15, column=3)

b1 = Button(window, text="philosophy", command = insertselect_phil, width=35)
b1.grid(row=16, column=3)

b1 = Button(window, text="sociology", command = insertselect_sociology, width=35)
b1.grid(row=17, column=3)

b1 = Button(window, text="core", command = insertupper_core, width=35)
b1.grid(row=18, column=3)                      


def close_window(): 
    
    
    # to close the GUI without shut the kernel
    window.destroy()
    
    
b1 = Button(window, text="Quit",command =close_window, width=25)
b1.grid(row=19,column=1)
    
    
    
def save():
    
    #display all the history record in a new page
    A = list1.get(0,END)
    messagebox.showinfo(title='history record',message = A)
    

    
b1 = Button(window, text="save",command =save, width=25)
b1.grid(row=19,column=2)   







window.mainloop()
